# %% [markdown]
# # run thses commands in anaconda promptshell

# %%
#conda create -n eda python=3.11
#conda activate eda
#pip install pandas ydata-profiling jupyter ipykernel
#python -m ipykernel install --user --name eda --display-name "Python (EDA)"

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\flat_house_data_feature_updated.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")
