# %%
import numpy as np 
import pandas as pd

# %%
flats=pd.read_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\Flats\flats_cleaned.csv')
houses=pd.read_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\independent_houses\houses_cleaned.csv')

# %%
df=pd.concat([flats,houses],ignore_index=True)

# %%
df
# Out:
#                                       property_name property_type  \
# 0                      2 BHK Flat in Krishna Colony          flat
# 1                         2 BHK Flat in Ashok Vihar          flat
# 2                               2 BHK Flat in Sohna          flat
# 3                   2 BHK Flat in Sector 61 Gurgaon          flat
# 4                   2 BHK Flat in Sector 92 Gurgaon          flat
# ...                                             ...           ...
# 3956  4 Bedroom House for sale in Sector 26 Gurgaon         house
# 3957        3 Bedroom House for sale in DLF Phase 2         house
# 3958  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3959  3 Bedroom House for sale in Sector 26 Gurgaon         house
# 3960             3 Bedroom House for sale in Bissar         house
#
#                                        society  price  price_per_sqft    area  \
# 0                       maa bhagwati residency   0.45          5000.0   900.0
# ...

# %%
df=df.sample(df.shape[0],ignore_index=True)

# %%
df
# Out:
#                                       property_name property_type  \
# 0                   2 BHK Flat in Sector 61 Gurgaon          flat
# 1                     2 BHK Flat in Sector-33 Sohna          flat
# 2     5 Bedroom House for sale in Sector 66 Gurgaon         house
# 3                  4 BHK Flat in Sector 70A Gurgaon          flat
# 4                  3 BHK Flat in Sector 104 Gurgaon          flat
# ...                                             ...           ...
# 3956                3 BHK Flat in Sector 70 Gurgaon          flat
# 3957                2 BHK Flat in Sector 65 Gurgaon          flat
# 3958                2 BHK Flat in Sector 61 Gurgaon          flat
# 3959                4 BHK Flat in Sector 92 Gurgaon          flat
# 3960                2 BHK Flat in Sector 89 Gurgaon          flat
#
#                       society  price  price_per_sqft    area  \
# 0                pioneer park   1.60         11594.0  1380.0
# ...

# %%
df.to_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\flat_house_data.csv',index=False)
