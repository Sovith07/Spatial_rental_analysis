# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\flat_house_data.csv')

# %%
df.sample(5)
# Out:
#                           property_name property_type                society  \
# 1959    2 BHK Flat in Sector 66 Gurgaon          flat            ireo uptown
# 2742        3 BHK Flat in Dharam Colony          flat     krishna appartment
# 2726  2 BHK Flat in Sector 89 A Gurgaon          flat  adani aangan galleria
# 41      3 BHK Flat in Sector 65 Gurgaon          flat            m3m skycity
# 3838    2 BHK Flat in Sector 85 Gurgaon          flat             godrej air
#
#       price  price_per_sqft    area  \
# 1959   1.32         11442.0  1154.0
# 2742   0.35          3500.0  1000.0
# 2726   0.42          4941.0   850.0
# 41     2.85         15590.0  1828.0
# 3838   1.30         14541.0   894.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 1959             Super Built up area 1158(107.58 sq.m.)        2         2
# 2742               Super Built up area 1000(92.9 sq.m.)        3         3
# 2726               Super Built up area 850(78.97 sq.m.)        2         2
# 41               Super Built up area 1828(169.83 sq.m.)        3         3
# 3838  Super Built up area 1400(130.06 sq.m.)Carpet a...        2         2
#
#      balcony additionalRoom                                address  floorNum  \
# 1959       2             na    Sector 66 Gurgaon, Gurgaon, Haryana       6.0
# 2742       1             na        Dharam Colony, Gurgaon, Haryana       2.0
# 2726       2             na  Sector 89 A Gurgaon, Gurgaon, Haryana       3.0
# 41         3             na    Sector 65 Gurgaon, Gurgaon, Haryana      43.0
# 3838       3             na    Sector 85 Gurgaon, Gurgaon, Haryana      30.0
#
#      facing    agePossession  \
# 1959    NaN  1 to 5 Year Old
# 2742    NaN     10+ Year Old
# 2726    NaN  1 to 5 Year Old
# 41    South         Dec 2024
# 3838    NaN         Nov 2023
#
#                                         nearbyLocations  \
# 1959  ['Hub 66', 'Shiksha Bharti Public School', 'VI...
# 2742  ['Palam triangle', 'Palam Vihar Vyapar kendra'...
# 2726  ['Indian Oil', 'Essar Petrol Pump', 'Garhi har...
# 41    ['Sector 55 Metro Station', 'Eros City Square'...
# 3838  ['Sapphire 83 Mall', 'Sector 86 Road', 'Dwarka...
#
#                                             description  \
# 1959  Residential apartment for sell.The property co...
# 2742  Residential apartment for sell.Located on 2nd ...
# 2726  Residential apartment for sell.Located in sect...
# 41    M3m skycity is one of the most popular destina...
# 3838  Sun facing spacious 2bhk in luxurious society ...
#
#                                          furnishDetails  \
# 1959  ['1 Bed', '1 Light', '1 AC', 'No Chimney', 'No...
# 2742  ['3 Wardrobe', '3 Fan', '3 Light', 'No AC', 'N...
# 2726                                                 []
# 41    ['1 Exhaust Fan', '1 AC', '1 Chimney', '1 Modu...
# 3838                                                NaN
#
#                                                features  \
# 1959  ['Power Back-up', 'Intercom Facility', 'Lift(s...
# 2742                                                NaN
# 2726                                                NaN
# 41    ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 3838  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
#
#                                                  rating
# 1959  ['Green Area5 out of 5', 'Construction5 out of...
# 2742  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 2726                                                NaN
# 41    ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3838  ['Environment5 out of 5', 'Lifestyle5 out of 5...

# %%
df.shape
# Out:
# (3961, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# property_name         0
# property_type         0
# society             570
# price                20
# price_per_sqft       20
# area                 20
# areaWithType          0
# bedRoom               0
# bathroom              0
# balcony               0
# additionalRoom        0
# address              11
# floorNum             21
# facing             1177
# agePossession         1
# nearbyLocations     207
# description           0
# furnishDetails     1032
# features            709
# rating              450
# dtype: int64

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('Gurgaon','').str.strip())

# %%
df.head()
# Out:
#                                    property_name property_type  \
# 0                2 BHK Flat in Sector 61 Gurgaon          flat
# 1                  2 BHK Flat in Sector-33 Sohna          flat
# 2  5 Bedroom House for sale in Sector 66 Gurgaon         house
# 3               4 BHK Flat in Sector 70A Gurgaon          flat
# 4               3 BHK Flat in Sector 104 Gurgaon          flat
#
#                 society           sector  price  price_per_sqft    area  \
# 0          pioneer park        Sector 61   1.60         11594.0  1380.0
# 1    godrej nature plus  Sector-33 Sohna   1.15         11558.0   995.0
# 2    emaar mgf marbella        Sector 66    NaN             NaN     NaN
# 3  bptp astaire gardens       Sector 70A   1.60          8658.0  1848.0
# 4           ats triumph       Sector 104   1.75          7641.0  2290.0
#
#                                         areaWithType  bedRoom  bathroom  ...  \
# 0                   Carpet area: 1380 (128.21 sq.m.)        2         2  ...
# 1                                 Carpet area: 92.44        2         2  ...
# 2                        Plot area 350(292.64 sq.m.)        5         5  ...
# 3  Super Built up area 1848(171.68 sq.m.)Built Up...        4         4  ...
# 4  Super Built up area 2290(212.75 sq.m.)Carpet a...        3         4  ...
#
#                               additionalRoom  \
# 0                               servant room
# 1                                         na
# 2                                         na
# 3                          study room,others
# 4  pooja room,study room,servant room,others
#
#                                              address floorNum      facing  \
# 0                Sector 61 Gurgaon, Gurgaon, Haryana     21.0         NaN
# 1  Tower G 15th Floor, Sector-33 Sohna, Gurgaon, ...     15.0         NaN
# 2                Sector 66 Gurgaon, Gurgaon, Haryana      2.0         NaN
# 3          H33, Sector 70A Gurgaon, Gurgaon, Haryana      1.0         NaN
# 4               Sector 104 Gurgaon, Gurgaon, Haryana     12.0  North-West
#
#      agePossession                                    nearbyLocations  \
# 0  1 to 5 Year Old  ['Sector 55-56 Rapid Metro', 'Hong Kong Bazaar...
# 1         Dec 2023  ['Signature Global Infinity Mall Sohna', 'Bads...
# 2  1 to 5 Year Old  ['Sector 55-56 Rapid Metro Station', 'HUB 66',...
# 3  1 to 5 Year Old  ['Sector 54 Chowk Metro Station', 'Airia Mall'...
# 4  1 to 5 Year Old  ['IFFCO Chowk Metro Station', 'The Esplanade M...
#
#                                          description  \
# 0  Check out this 2 bhk flat for sale in pioneer ...
# 1  1.A one-Of-Its-Kind home with three pillars of...
# 2  This property situated in marbella sector 65 g...
# 3  Bptp astaire gardens is one of gurgaon's most ...
# 4  This 3 bhk flat is located in ats triumph, whi...
#
#                                       furnishDetails  \
# 0  ['2 Wardrobe', 'No AC', 'No Bed', 'No Chimney'...
# 1  ['3 Fan', '1 Exhaust Fan', '5 Light', 'No AC',...
# 2  ['5 Fan', '1 Exhaust Fan', '6 Geyser', '1 Micr...
# 3  ['1 Fan', '1 Light', '2 Chimney', '4 AC', 'No ...
# 4  ['4 Wardrobe', '7 Fan', '19 Light', '1 Chimney...
#
#                                             features  \
# 0  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 1  ['Intercom Facility', 'Lift(s)', 'Swimming Poo...
# 2  ['Private Garden / Terrace', 'Maintenance Staf...
# 3  ['Feng Shui / Vaastu Compliant', 'Security / F...
# 4  ['Intercom Facility', 'Lift(s)', 'Maintenance ...
#
#                                               rating
# 0  ['Green Area5 out of 5', 'Construction3 out of...
# 1                                                NaN
# 2  ['Environment3 out of 5', 'Safety4 out of 5', ...
# 3  ['Green Area4 out of 5', 'Construction5 out of...
# 4  ['Green Area4 out of 5', 'Construction5 out of...
#
# [5 rows x 21 columns]

# %%
df['sector'] = df['sector'].str.lower()

# %%
df['sector'] = df['sector'].str.replace('dharam colony','sector 12')
df['sector'] = df['sector'].str.replace('krishna colony','sector 7')
df['sector'] = df['sector'].str.replace('suncity','sector 54')
df['sector'] = df['sector'].str.replace('prem nagar','sector 13')
df['sector'] = df['sector'].str.replace('mg road','sector 28')
df['sector'] = df['sector'].str.replace('gandhi nagar','sector 28')
df['sector'] = df['sector'].str.replace('laxmi garden','sector 11')
df['sector'] = df['sector'].str.replace('shakti nagar','sector 11')
df['sector'] = df['sector'].str.replace('baldev nagar','sector 7')
df['sector'] = df['sector'].str.replace('shivpuri','sector 7')
df['sector'] = df['sector'].str.replace('garhi harsaru','sector 17')
df['sector'] = df['sector'].str.replace('imt manesar','manesar')
df['sector'] = df['sector'].str.replace('adarsh nagar','sector 12')
df['sector'] = df['sector'].str.replace('shivaji nagar','sector 11')
df['sector'] = df['sector'].str.replace('bhim nagar','sector 6')
df['sector'] = df['sector'].str.replace('madanpuri','sector 7')
df['sector'] = df['sector'].str.replace('saraswati vihar','sector 28')
df['sector'] = df['sector'].str.replace('arjun nagar','sector 8')
df['sector'] = df['sector'].str.replace('ravi nagar','sector 9')
df['sector'] = df['sector'].str.replace('vishnu garden','sector 105')
df['sector'] = df['sector'].str.replace('bhondsi','sector 11')
df['sector'] = df['sector'].str.replace('surya vihar','sector 21')
df['sector'] = df['sector'].str.replace('devilal colony','sector 9')
df['sector'] = df['sector'].str.replace('valley view estate','gwal pahari')
df['sector'] = df['sector'].str.replace('mehrauli  road','sector 14')
df['sector'] = df['sector'].str.replace('jyoti park','sector 7')
df['sector'] = df['sector'].str.replace('ansal plaza','sector 23')
df['sector'] = df['sector'].str.replace('dayanand colony','sector 6')
df['sector'] = df['sector'].str.replace('sushant lok phase 2','sector 55')
df['sector'] = df['sector'].str.replace('chakkarpur','sector 28')
df['sector'] = df['sector'].str.replace('greenwood city','sector 45')
df['sector'] = df['sector'].str.replace('subhash nagar','sector 12')
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')
df['sector'] = df['sector'].str.replace('malibu town','sector 47')
df['sector'] = df['sector'].str.replace('surat nagar 1','sector 104')
df['sector'] = df['sector'].str.replace('new colony','sector 7')
df['sector'] = df['sector'].str.replace('mianwali colony','sector 12')
df['sector'] = df['sector'].str.replace('jacobpura','sector 12')
df['sector'] = df['sector'].str.replace('rajiv nagar','sector 13')
df['sector'] = df['sector'].str.replace('ashok vihar','sector 3')
df['sector'] = df['sector'].str.replace('dlf phase 1','sector 26')
df['sector'] = df['sector'].str.replace('nirvana country','sector 50')
df['sector'] = df['sector'].str.replace('palam vihar','sector 2')
df['sector'] = df['sector'].str.replace('dlf phase 2','sector 25')
df['sector'] = df['sector'].str.replace('sushant lok phase 1','sector 43')
df['sector'] = df['sector'].str.replace('laxman vihar','sector 4')
df['sector'] = df['sector'].str.replace('dlf phase 4','sector 28')
df['sector'] = df['sector'].str.replace('dlf phase 3','sector 24')
df['sector'] = df['sector'].str.replace('sushant lok phase 3','sector 57')
df['sector'] = df['sector'].str.replace('dlf phase 5','sector 43')
df['sector'] = df['sector'].str.replace('rajendra park','sector 105')
df['sector'] = df['sector'].str.replace('uppals southend','sector 49')
df['sector'] = df['sector'].str.replace('sohna','sohna road')
df['sector'] = df['sector'].str.replace('ashok vihar phase 3 extension','sector 5')
df['sector'] = df['sector'].str.replace('south city 1','sector 41')
df['sector'] = df['sector'].str.replace('ashok vihar phase 2','sector 5')
df['sector'] = df['sector'].str.replace('sohna road road','sohna road')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road                    175
# sector 102                    113
# sector 85                     110
# sector 92                     104
# sector 69                      94
# sector 81                      90
# sector 65                      90
# sector 90                      90
# sector 109                     88
# sector 79                      80
# sector 33                      74
# sector 104                     73
# sector 83                      69
# sector 37d                     68
# sector 43                      67
# sector 86                      67
# sector 95                      66
# sector 50                      65
# sector 89                      64
# sector 2                       63
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 48                      56
# sector 70a                     54
# sector 37c                     53
# sector 70                      53
# sector 84                      51
# sector 26                      50
# sector 4                       49
# sector 67                      48
# sector 49                      48
# sector 28                      47
# sector 66                      46
# sector 103                     45
# sector 25                      43
# sector 113                     43
# sector 61                      42
# sector 82                      42
# sector 7                       39
# sector 106                     38
# sector 12                      37
# manesar                        33
# sector 99a                     32
# sector 54                      31
# sector 68                      30
# sector 77                      29
# sector 72                      29
# sector 71                      27
# sector 24                      24
# sector 57                      24
# sector 112                     24
# sector 3                       24
# sector 105                     23
# sector 88a                     23
# sector 14                      23
# sector 67a                     22
# sector 111                     22
# sector 11                      21
# sector 22                      20
# sector 82a                     20
# sector 110                     19
# sector 78                      19
# sector 47                      19
# gwal pahari                    18
# sector 63a                     18
# sector 74                      18
# sector 91                      17
# sector 62                      17
# sector 99                      16
# sector 60                      15
# sector 63                      15
# sector 52                      14
# sector 55                      14
# sector 53                      14
# sector 76                      14
# sector 46                      13
# sector 6                       13
# sector 23                      13
# sector 9                       13
# sector 36a                     13
# sector 31                      12
# sector 39                      12
# sector 38                      12
# sector 93                      12
# sector 36                      11
# sector 41                      11
# sector 3 phase 3 extension     11
# sector 9a                      11
# sector 13                      10
# sector 45                       9
# sector 3 phase 2                9
# sector 40                       8
# sector 17                       8
# sector 59                       8
# sector 8                        8
# dwarka expressway               8
# sector 10a                      8
# sector 51                       7
# sector 58                       7
# sector 5                        6
# sector 21                       6
# sector 1                        6
# sector 15                       6
# sector 80                       5
# new sector 2                    5
# sector 30                       5
# new                             4
# sector 73                       3
# sector 88b                      3
# sector 17a                      3
# sector 17b                      3
# sector 27                       3
# Name: count, dtype: int64

# %%
df['sector'] = df['sector'].str.replace('sector 95a','sector 95')
df['sector'] = df['sector'].str.replace('sector 23a','sector 23')
df['sector'] = df['sector'].str.replace('sector 12a','sector 12')
df['sector'] = df['sector'].str.replace('sector 3a','sector 3')
df['sector'] = df['sector'].str.replace('sector 110 a','sector 110')
df['sector'] = df['sector'].str.replace('patel nagar','sector 15')
df['sector'] = df['sector'].str.replace('a block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('maruti kunj','sector 12')
df['sector'] = df['sector'].str.replace('b block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector-33 sohna road','sector 33')
df['sector'] = df['sector'].str.replace('sector 1 manesar','manesar')
df['sector'] = df['sector'].str.replace('sector 4 phase 2','sector 4')
df['sector'] = df['sector'].str.replace('sector 1a manesar','manesar')
df['sector'] = df['sector'].str.replace('c block sector 43','sector 43')
df['sector'] = df['sector'].str.replace('sector 89 a','sector 89')
df['sector'] = df['sector'].str.replace('sector 2 extension','sector 2')
df['sector'] = df['sector'].str.replace('sector 36 sohna road','sector 36')

# %%
df['sector'].value_counts()
# Out:
# sector
# sohna road                    175
# sector 102                    113
# sector 85                     110
# sector 92                     104
# sector 69                      94
# sector 81                      90
# sector 65                      90
# sector 90                      90
# sector 109                     88
# sector 79                      80
# sector 33                      74
# sector 104                     73
# sector 83                      69
# sector 37d                     68
# sector 43                      67
# sector 86                      67
# sector 95                      66
# sector 50                      65
# sector 89                      64
# sector 2                       63
# sector 107                     60
# sector 108                     59
# sector 56                      57
# sector 48                      56
# sector 70a                     54
# sector 37c                     53
# sector 70                      53
# sector 84                      51
# sector 26                      50
# sector 4                       49
# sector 67                      48
# sector 49                      48
# sector 28                      47
# sector 66                      46
# sector 103                     45
# sector 25                      43
# sector 113                     43
# sector 61                      42
# sector 82                      42
# sector 7                       39
# sector 106                     38
# sector 12                      37
# manesar                        33
# sector 99a                     32
# sector 54                      31
# sector 68                      30
# sector 77                      29
# sector 72                      29
# sector 71                      27
# sector 24                      24
# sector 57                      24
# sector 112                     24
# sector 3                       24
# sector 105                     23
# sector 88a                     23
# sector 14                      23
# sector 67a                     22
# sector 111                     22
# sector 11                      21
# sector 22                      20
# sector 82a                     20
# sector 110                     19
# sector 78                      19
# sector 47                      19
# gwal pahari                    18
# sector 63a                     18
# sector 74                      18
# sector 91                      17
# sector 62                      17
# sector 99                      16
# sector 60                      15
# sector 63                      15
# sector 52                      14
# sector 55                      14
# sector 53                      14
# sector 76                      14
# sector 46                      13
# sector 6                       13
# sector 23                      13
# sector 9                       13
# sector 36a                     13
# sector 31                      12
# sector 39                      12
# sector 38                      12
# sector 93                      12
# sector 36                      11
# sector 41                      11
# sector 3 phase 3 extension     11
# sector 9a                      11
# sector 13                      10
# sector 45                       9
# sector 3 phase 2                9
# sector 40                       8
# sector 17                       8
# sector 59                       8
# sector 8                        8
# dwarka expressway               8
# sector 10a                      8
# sector 51                       7
# sector 58                       7
# sector 5                        6
# sector 21                       6
# sector 1                        6
# sector 15                       6
# sector 80                       5
# new sector 2                    5
# sector 30                       5
# new                             4
# sector 73                       3
# sector 88b                      3
# sector 17a                      3
# sector 17b                      3
# sector 27                       3
# Name: count, dtype: int64

# %%
df[df['sector'] == 'new']
# Out:
#                   property_name property_type                       society  \
# 884   4 BHK Flat in New Gurgaon          flat                        dlf 76
# 1406  2 BHK Flat in New Gurgaon          flat                   green court
# 2179  2 BHK Flat in New Gurgaon          flat  takshila heights sector 37 c
# 2330  4 BHK Flat in New Gurgaon          flat                    sare homes
#
#      sector  price  price_per_sqft    area  \
# 884     new   4.00         11428.0  3500.0
# 1406    new   0.38          5507.0   690.0
# 2179    new   0.67          5583.0  1200.0
# 2330    new   0.85          4786.0  1776.0
#
#                                 areaWithType  bedRoom  bathroom  ...  \
# 884         Carpet area: 3500 (325.16 sq.m.)        4         4  ...
# 1406           Carpet area: 690 (64.1 sq.m.)        2         2  ...
# 2179  Super Built up area 1200(111.48 sq.m.)        2         2  ...
# 2330     Super Built up area 1776(165 sq.m.)        4         4  ...
#
#                additionalRoom                        address floorNum  facing  \
# 884   study room,servant room  New Gurgaon, Gurgaon, Haryana      4.0     NaN
# 1406                       na  New Gurgaon, Gurgaon, Haryana      7.0     NaN
# 2179                       na  New Gurgaon, Gurgaon, Haryana      3.0     NaN
# 2330                       na  New Gurgaon, Gurgaon, Haryana      3.0     NaN
#
#            agePossession                                    nearbyLocations  \
# 884             Jun 2027  ['Shri Balaji Hospital and Trauma Center', 'S....
# 1406  Under Construction  ['Ing bank ATM', 'Dcb bank ATM', 'Indus ind ba...
# 2179     1 to 5 Year Old  ['Shri Balaji Hospital and Trauma Center', 'S....
# 2330    5 to 10 Year Old  ['Columbia Asia Hospital', 'Apex Multi Special...
#
#                                             description  \
# 884   This lovely 4 bhk apartment/flat in new gurgao...
# 1406  We are the proud owners of this 2 bhk apartmen...
# 2179  Check out this 2 bhk apartment for sale in tak...
# 2330  Located in the popular residential address of ...
#
#                                          furnishDetails  \
# 884   ['6 Wardrobe', '1 Fridge', '8 Fan', '1 Exhaust...
# 1406                                                 []
# 2179                                                 []
# 2330                                                 []
#
#                                                features rating
# 884   ['Security / Fire Alarm', 'Feng Shui / Vaastu ...    NaN
# 1406  ['Intercom Facility', 'Lift(s)', 'Maintenance ...    NaN
# 2179  ['Lift(s)', 'Swimming Pool', 'Visitor Parking'...    NaN
# 2330                                                NaN    NaN
#
# [4 rows x 21 columns]

# %%
df[df['sector'] == 'new sector 2']
# Out:
#                                     property_name property_type  \
# 603   3 Bedroom House for sale in New Palam Vihar         house
# 1365                2 BHK Flat in New Palam Vihar          flat
# 2475                2 BHK Flat in New Palam Vihar          flat
# 3204                2 BHK Flat in New Palam Vihar          flat
# 3600  2 Bedroom House for sale in New Palam Vihar         house
#
#                   society        sector  price  price_per_sqft    area  \
# 603                   NaN  new sector 2   1.00          8796.0  1137.0
# 1365              my home  new sector 2   0.28          3166.0   884.0
# 2475              my home  new sector 2   0.22          4400.0   500.0
# 3204  ompee k s residency  new sector 2   1.60         26936.0   594.0
# 3600              my home  new sector 2   0.34         12592.0   270.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 603   Plot area 120(100.34 sq.m.)Built Up area: 120 ...        3         2
# 1365                     Carpet area: 900 (83.61 sq.m.)        2         1
# 2475                     Carpet area: 500 (46.45 sq.m.)        2         2
# 3204                      Carpet area: 66 (55.18 sq.m.)        2         2
# 3600                         Plot area 270(25.08 sq.m.)        2         2
#
#       ... additionalRoom                                            address  \
# 603   ...     pooja room  Q-148, New Palam Vihar, Phase-2, Near Royal Oa...
# 1365  ...         others         F 150/b, New Palam Vihar, Gurgaon, Haryana
# 2475  ...             na                  New Palam Vihar, Gurgaon, Haryana
# 3204  ...             na                  New Palam Vihar, Gurgaon, Haryana
# 3600  ...             na         Ez-19 A, New Palam Vihar, Gurgaon, Haryana
#
#      floorNum  facing     agePossession  \
# 603       1.0   North      10+ Year Old
# 1365      2.0     NaN   1 to 5 Year Old
# 2475      1.0     NaN   0 to 1 Year Old
# 3204      1.0     NaN   1 to 5 Year Old
# 3600      3.0    West  5 to 10 Year Old
#
#                                         nearbyLocations  \
# 603   ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 1365  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 2475  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3204  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
# 3600  ['Palam Vihar Vyapar kendra', 'Palam triangle'...
#
#                                             description  \
# 603   Ground and first floor, Ground floor: Ground f...
# 1365  2 bhk room with wooden coverd ,1 drawing room,...
# 2475  Cctv surveillance are provided here. There is ...
# 3204  We are the proud owners of this 2 bhk apartmen...
# 3600  There are availability of various facilities l...
#
#                                          furnishDetails  \
# 603                                                 NaN
# 1365  ['3 Wardrobe', '5 Light', '1 Chimney', '1 Modu...
# 2475  ['3 Fan', '1 Exhaust Fan', '15 Light', '1 Modu...
# 3204                                                NaN
# 3600  ['1 Wardrobe', '3 Fan', '6 Light', 'No AC', 'N...
#
#                                           features  \
# 603                                            NaN
# 1365                     ['Water Storage', 'Park']
# 2475                                           NaN
# 3204                                           NaN
# 3600  ['Water Storage', 'Park', 'Visitor Parking']
#
#                                                  rating
# 603   ['Environment4 out of 5', 'Lifestyle4 out of 5...
# 1365  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 2475  ['Safety4 out of 5', 'Lifestyle4 out of 5', 'E...
# 3204  ['Environment4 out of 5', 'Safety4 out of 5', ...
# 3600  ['Environment4 out of 5', 'Lifestyle4 out of 5...
#
# [5 rows x 21 columns]

# %%
df.loc[[311,1072,1486,3040,3875],'sector'] = 'sector 110'

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.to_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\flat_house_data_cleaned.csv',index=False)
