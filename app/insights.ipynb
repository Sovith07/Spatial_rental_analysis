# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from sklearn.decomposition import PCA

# %%
df=pd.read_csv(r'D:\vs code projects\rental_analysis\data\interim\Gurugram\flat_house_feature_selection.csv_v2')

# %%
df['agePossession'] = df['agePossession'].replace(
    {
        'Relatively New':'new',
        'Moderately Old':'old',
        'New Property' : 'new',
        'Old Property' : 'old',
        'Under Construction' : 'under construction'
    }
)

# %%
df['property_type'] = df['property_type'].replace({'flat':0,'house':1})

# %%
df['luxury_category'] = df['luxury_category'].replace({'Low':0,'Medium':1,'High':2})

# %%
new_df = pd.get_dummies(df,columns=['sector','agePossession'],drop_first=True)

# %%
new_df.drop(columns=['store room','floor_category','balcony'],inplace=True)

# %%
X = new_df.drop(columns=['price'])
y = new_df['price']

# %%
y_log = np.log1p(y)

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled = pd.DataFrame(X_scaled,columns=X.columns)

# %%
kfold = KFold(n_splits=10, shuffle=True, random_state=42)
scores = cross_val_score(LinearRegression(), X_scaled, y_log, cv=kfold, scoring='r2')

# %%
scores.mean(),scores.std()
# Out:
# (np.float64(0.8544808585505257), np.float64(0.0318671491805699))

# %%
lr = LinearRegression()
ridge = Ridge(alpha=0.0001)

# %%
lr.fit(X_scaled,y_log)
# Out:
# LinearRegression()

# %%
ridge.fit(X_scaled,y_log)
# Out:
# Ridge(alpha=0.0001)

# %%
coef_df = pd.DataFrame(ridge.coef_.reshape(1,121),columns=X.columns).stack().reset_index().drop(columns=['level_0']).rename(columns={'level_1':'feature',0:'coef'})

# %%
coef_df
# Out:
#                               feature      coef
# 0                       property_type  0.121121
# 1                             bedRoom  0.048652
# 2                            bathroom  0.065772
# 3                       built_up_area  0.212856
# 4                        servant room  0.049762
# ..                                ...       ...
# 116                 sector_sector 99a -0.016791
# 117                  sector_sector 9a -0.007906
# 118                 sector_sohna road -0.037047
# 119                 agePossession_old -0.003935
# 120  agePossession_under construction  0.015230
#
# [121 rows x 2 columns]

# %%
beta_standardized=coef_df[coef_df['feature']=='bedRoom']['coef']

# %%
# 1. Import necessary libraries
import statsmodels.api as sm

# 2. Add a constant to X
X_with_const = sm.add_constant(X_scaled)

# 3. Fit the model
model = sm.OLS(y_log, X_with_const).fit()

# 4. Obtain summary statistics
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.867
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     190.6
# Date:                Fri, 31 Jul 2026   Prob (F-statistic):               0.00
# Time:                        16:41:15   Log-Likelihood:                 652.27
# No. Observations:                3655   AIC:                            -1061.
# Df Residuals:                    3533   BIC:                            -303.7
# Df Model:                         121
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# const                                 1.0421      0.003    305.999      0.000       1.035       1.049
# property_type                         0.1211      0.005     23.417      0.000       0.111       0.131
# bedRoom                               0.0487      0.008      6.168      0.000       0.033       0.064
# bathroom                              0.0658      0.008      8.037      0.000       0.050       0.082
# built_up_area                         0.2129      0.005     43.552      0.000       0.203       0.222
# servant room                          0.0498      0.004     11.128      0.000       0.041       0.059
# furnishing_type                       0.0084      0.004      2.118      0.034       0.001       0.016
# sector_sector 70a                     0.0120      0.010      1.189      0.235      -0.008       0.032
# sector_sector 71                     -0.0070      0.008     -0.923      0.356      -0.022       0.008
# sector_sector 72                      0.0263      0.008      3.384      0.001       0.011       0.042
# sector_sector 73                     -0.0027      0.004     -0.666      0.506      -0.011       0.005
# sector_sector 74                      0.0191      0.006      2.948      0.003       0.006       0.032
# sector_sector 76                     -0.0029      0.006     -0.499      0.618      -0.015       0.009
# sector_sector 77                     -0.0029      0.008     -0.373      0.709      -0.018       0.012
# sector_sector 78                     -0.0079      0.006     -1.220      0.222      -0.021       0.005
# sector_sector 79                      0.0072      0.012      0.600      0.548      -0.016       0.031
# sector_sector 8                      -0.0167      0.005     -3.419      0.001      -0.026      -0.007
# sector_sector 80                     -0.0015      0.004     -0.330      0.741      -0.010       0.007
# sector_sector 81                      0.0094      0.013      0.739      0.460      -0.015       0.034
# sector_sector 82                     -0.0039      0.009     -0.430      0.668      -0.022       0.014
# sector_sector 82a                     0.0077      0.007      1.146      0.252      -0.005       0.021
# sector_sector 83                     -0.0061      0.011     -0.542      0.588      -0.028       0.016
# sector_sector 84                     -0.0144      0.010     -1.471      0.141      -0.034       0.005
# sector_sector 85                      0.0022      0.014      0.162      0.871      -0.025       0.029
# sector_sector 86                     -0.0095      0.011     -0.872      0.383      -0.031       0.012
# sector_sector 88a                     0.0071      0.007      0.999      0.318      -0.007       0.021
# sector_sector 88b                    -0.0012      0.004     -0.305      0.760      -0.009       0.007
# sector_sector 89                     -0.0018      0.011     -0.164      0.870      -0.023       0.019
# sector_sector 9                      -0.0148      0.006     -2.680      0.007      -0.026      -0.004
# sector_sector 90                     -0.0188      0.013     -1.487      0.137      -0.044       0.006
# sector_sector 91                     -0.0029      0.006     -0.451      0.652      -0.015       0.010
# sector_sector 92                     -0.0350      0.013     -2.598      0.009      -0.061      -0.009
# sector_sector 93                     -0.0060      0.005     -1.093      0.274      -0.017       0.005
# sector_sector 95                     -0.0313      0.010     -2.989      0.003      -0.052      -0.011
# sector_sector 99                      0.0005      0.006      0.076      0.939      -0.012       0.013
# sector_sector 99a                    -0.0168      0.008     -2.084      0.037      -0.033      -0.001
# sector_sector 9a                     -0.0079      0.006     -1.436      0.151      -0.019       0.003
# sector_sohna road                    -0.0370      0.017     -2.196      0.028      -0.070      -0.004
# agePossession_old                    -0.0039      0.005     -0.809      0.418      -0.013       0.006
# agePossession_under construction      0.0152      0.004      3.833      0.000       0.007       0.023
# ==============================================================================
# Omnibus:                      544.859   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5191.660
# Skew:                          -0.397   Prob(JB):                         0.00
# Kurtosis:                       8.784   Cond. No.                         43.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
sd_y=y_log.std()

# %%
sd_x=X_scaled['bedRoom'].std()

# %%
beta_original=(sd_y*beta_standardized)/(sd_x)

# %%
beta_original
# Out:
# 1    0.027023
# Name: coef, dtype: float64

# %%
np.expm1(beta_original)
# Out:
# 1    0.027392
# Name: coef, dtype: float64
